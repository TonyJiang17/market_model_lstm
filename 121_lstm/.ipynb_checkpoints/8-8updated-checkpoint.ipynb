# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
from keras.layers import Dense, LSTM, TimeDistributed
py.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = pd.read_csv(filepath_or_buffer="./Data/clean_data.csv", index_col="date")

# %%
data.head()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU  spindx GOLDPMGBD228NLBM  exalus  \
# date
# 19870520       8.05        8.92        18.63  278.21          475.250  1.3820
# 19870521       8.06        8.87        18.45  280.17          469.100  1.3864
# 19870522       7.97        8.78        18.55  282.16          466.500  1.3883
# 19870526       7.79        8.55        18.63  289.11          449.000  1.4029
# 19870527       7.84        8.60        18.60  288.73          449.500  1.3988
#
#           exjpus  exukus
# date
# 19870520  139.78  0.5942
# 19870521  140.45  0.5956
# 19870522  140.60  0.5977
# 19870526  143.30  0.6120
# 19870527  143.52  0.6200

# %%
data.tail()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU   spindx GOLDPMGBD228NLBM  \
# date
# 20181029       2.81        3.08        77.56  2641.25          1230.80
# 20181030       2.84        3.12        75.68  2682.63          1225.40
# 20181031       2.87        3.15        74.84  2711.74          1214.95
# 20181101       2.84        3.14        71.25  2740.37          1231.15
# 20181102       2.91        3.22        71.11  2723.06          1232.10
#
#           exalus  exjpus  exukus
# date
# 20181029  1.4136  112.49  0.7808
# 20181030  1.4061  112.76  0.7855
# 20181031  1.4104  112.86  0.7825
# 20181101  1.3910  112.79  0.7708
# 20181102  1.3891  113.09  0.7713

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7931 non-null object
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7931 non-null object
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 557.6+ KB

# %%
data = data.apply(pd.to_numeric, errors = "coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7858 non-null float64
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7734 non-null float64
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(8)
# memory usage: 557.6 KB

# %%
data['spindx'].replace(0, np.nan, inplace=True)
data['spindx'].fillna(method='ffill', inplace=True)

# %%
#reshaping prediction value into value range -1 to 1
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # MULTIVARIATE PREDICTION (WITH LOOKBACK AND TIMESTEPS)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
data.columns
#values = data[['exukus'] + ['Volume (BTC)'] + ['Volume (Currency)']].values
#values = values.astype('float32')
# Out:
# Index(['TCMNOM_Y2', 'TCMNOM_Y10', 'DCOILBRENTEU', 'spindx', 'GOLDPMGBD228NLBM',
#        'exalus', 'exjpus', 'exukus'],
#       dtype='object')

# %%
number_of_variables = 8
values = data[['spindx'] + ['TCMNOM_Y2'] + ['TCMNOM_Y10'] + ['DCOILBRENTEU'] + ['GOLDPMGBD228NLBM'] + ['exalus'] + ['exjpus'] + ['exukus']].values
values = values.astype('float32')

# %%
values
# Out:
# array([[2.78210e+02, 8.05000e+00, 8.92000e+00, ..., 1.38200e+00,
#         1.39780e+02, 5.94200e-01],
#        [2.80170e+02, 8.06000e+00, 8.87000e+00, ..., 1.38640e+00,
#         1.40450e+02, 5.95600e-01],
#        [2.82160e+02, 7.97000e+00, 8.78000e+00, ..., 1.38830e+00,
#         1.40600e+02, 5.97700e-01],
#        ...,
#        [2.71174e+03, 2.87000e+00, 3.15000e+00, ..., 1.41040e+00,
#         1.12860e+02, 7.82500e-01],
#        [2.74037e+03, 2.84000e+00, 3.14000e+00, ..., 1.39100e+00,
#         1.12790e+02, 7.70800e-01],
#        [2.72306e+03, 2.91000e+00, 3.22000e+00, ..., 1.38910e+00,
#         1.13090e+02, 7.71300e-01]], dtype=float32)

# %%
look_back = 3 
time_steps = 1
series_to_supervised(values, look_back, time_steps)
reframed = series_to_supervised(values, look_back, time_steps)
reframed.tail()
# Out:
#         var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)    var5(t-3)  var6(t-3)  \
# 7926  2656.100098       2.84       3.10  77.339996  1230.550049     1.4140
# 7927  2705.570068       2.86       3.14  77.300003  1230.800049     1.4116
# 7928  2658.689941       2.81       3.08  77.400002  1233.849976     1.4108
# 7929  2641.250000       2.81       3.08  77.559998  1230.800049     1.4136
# 7930  2682.629883       2.84       3.12  75.680000  1225.400024     1.4061
#
#        var7(t-3)  var8(t-3)    var1(t-2)  var2(t-2)  ...   var7(t-1)  \
# 7926  112.580002     0.7753  2705.570068       2.86  ...  111.650002
# 7927  112.540001     0.7796  2658.689941       2.81  ...  112.489998
# 7928  111.650002     0.7797  2641.250000       2.81  ...  112.760002
# 7929  112.489998     0.7808  2682.629883       2.84  ...  112.860001
# 7930  112.760002     0.7855  2711.739990       2.87  ...  112.790001
#
#       var8(t-1)      var1(t)  var2(t)  var3(t)    var4(t)      var5(t)  \
# 7926     0.7797  2641.250000     2.81     3.08  77.559998  1230.800049
# 7927     0.7808  2682.629883     2.84     3.12  75.680000  1225.400024
# 7928     0.7855  2711.739990     2.87     3.15  74.839996  1214.949951
# 7929     0.7825  2740.370117     2.84     3.14  71.250000  1231.150024
# 7930     0.7708  2723.060059     2.91     3.22  71.110001  1232.099976
#
#       var6(t)     var7(t)  var8(t)
# 7926   1.4136  112.489998   0.7808
# 7927   1.4061  112.760002   0.7855
# 7928   1.4104  112.860001   0.7825
# 7929   1.3910  112.790001   0.7708
# 7930   1.3891  113.089996   0.7713
#
# [5 rows x 32 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(reframed)
# Out:
# /home/tjiang20/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning:
#
# Data with input dtype float32 were all converted to float64 by MinMaxScaler.

# %%
t = scaler.inverse_transform(scaled)
t[0]
# Out:
# array([278.20999146,   8.05000019,   8.92000008,  18.62999916,
#        475.25      ,   1.38199997, 139.77999878,   0.59420002,
#        280.17001343,   8.06000042,   8.86999989,  18.45000076,
#        469.1000061 ,   1.38639998, 140.44999695,   0.59560001,
#        282.16000366,   7.96999979,   8.77999973,  18.54999924,
#        466.5       ,   1.38829994, 140.6000061 ,   0.5977    ,
#        289.10998535,   7.78999996,   8.55000019,  18.62999916,
#        449.        ,   1.40289998, 143.30000305,   0.61199999])

# %%
n_train_hours = int(len(scaled) * 0.7)

train = scaled[:n_train_hours, :]
test = scaled[n_train_hours:, :]

# %%
# train_t = scaler.inverse_transform(test)
# train_t[-1]

# %%
# split into input and outputs
train_X, train_y = train[:, :-8], train[:, -8:]
test_X, test_y = test[:, :-8], test[:, -8:]

# %%
train_X.shape
# Out:
# (5068, 24)

# %%
train_y.shape
# Out:
# (5068, 8)

# %%
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
train_y = train_y.reshape((train_y.shape[0], 1, train_y.shape[1]))
test_y = test_y.reshape((test_y.shape[0], 1, test_y.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (5068, 1, 24) (5068, 1, 8) (2173, 1, 24) (2173, 1, 8)

# %% [markdown]
# # Building the Model

# %%
multi_model = Sequential()
multi_model.add(LSTM(
    input_shape=(train_X.shape[1],train_X.shape[2]),
    return_sequences=True, units=train_X.shape[1]))

multi_model.add(LSTM(
    300,
    return_sequences=True))
multi_model.add(TimeDistributed(Dense(number_of_variables)))
multi_model.compile(loss="mse", optimizer="adam")
multi_history = multi_model.fit(train_X, train_y, epochs=150, batch_size=150, validation_data=(test_X, test_y), verbose=0, shuffle=False)

# %%
# multi_model = Sequential()
# multi_model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
# multi_model.add(Dense(1))
# multi_model.compile(loss='mae', optimizer='adam')

# # Callbacks
# from keras.callbacks import ModelCheckpoint

# weight_path="{}_weights.hdf5".format('market_lstm_model')

# checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
#                              save_best_only=True, mode='min', save_weights_only = False)
# callbacks_list = [checkpoint]


# multi_history = multi_model.fit(train_X, train_y, epochs=40, batch_size=150, validation_data=(test_X, test_y), 
#                                 verbose=1, shuffle=False)#, callbacks = callbacks_list)

# %%
pyplot.plot(multi_history.history['loss'], label='multi_train')
pyplot.plot(multi_history.history['val_loss'], label='multi_test')
pyplot.legend()
pyplot.show()

# %%
yhat = multi_model.predict(test_X)

# %%
test_y.shape
# Out:
# (2173, 1, 8)

# %%
pyplot.plot(yhat[:,0][:,0], label='predict')
pyplot.plot(test_y[:,0][:,0], label='true')
pyplot.legend()
pyplot.show()

# %%
#reshape prediction
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
yhat = yhat.reshape((yhat.shape[0], yhat.shape[2]))

# %%
test_X.shape
# Out:
# (2173, 24)

# %%
inv_yhat = concatenate((test_X[:, :], yhat), axis=1)

# %%
inv_yhat.shape
# Out:
# (2173, 32)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
inv_yhat[-1]
# Out:
# array([2.68262988e+03, 2.83999991e+00, 3.11999989e+00, 7.56800003e+01,
#        1.22540002e+03, 1.40610003e+00, 1.12760002e+02, 7.85499990e-01,
#        2.71173999e+03, 2.86999989e+00, 3.15000010e+00, 7.48399963e+01,
#        1.21494995e+03, 1.41040003e+00, 1.12860001e+02, 7.82500029e-01,
#        2.74037012e+03, 2.83999991e+00, 3.14000010e+00, 7.12500000e+01,
#        1.23115002e+03, 1.39100003e+00, 1.12790001e+02, 7.70799994e-01,
#        1.13914815e+03, 3.03326817e+00, 4.47476116e+00, 1.08137218e+02,
#        1.02685148e+03, 1.07934202e+00, 1.14260281e+02, 5.06802812e-01])

# %%
#inv_yhat[:,-8:].shape

# %%
inv_yhat = inv_yhat[:,-8:]

# %%
inv_yhat[0]
# Out:
# array([1.23768271e+03, 2.91668138e+00, 4.17383188e+00, 7.75065287e+01,
#        7.39238105e+02, 1.28185731e+00, 1.10714619e+02, 5.50911668e-01])

# %%
#reshape actual
test_y = test_y.reshape((test_y.shape[0], test_y.shape[2]))

# %%
test_y.shape
# Out:
# (2173, 8)

# %%
inv_y = concatenate((test_X[:, :], test_y), axis=1)

# %%
inv_y = scaler.inverse_transform(inv_y)

# %%
inv_y[-1]
# Out:
# array([2.68262988e+03, 2.83999991e+00, 3.11999989e+00, 7.56800003e+01,
#        1.22540002e+03, 1.40610003e+00, 1.12760002e+02, 7.85499990e-01,
#        2.71173999e+03, 2.86999989e+00, 3.15000010e+00, 7.48399963e+01,
#        1.21494995e+03, 1.41040003e+00, 1.12860001e+02, 7.82500029e-01,
#        2.74037012e+03, 2.83999991e+00, 3.14000010e+00, 7.12500000e+01,
#        1.23115002e+03, 1.39100003e+00, 1.12790001e+02, 7.70799994e-01,
#        2.72306006e+03, 2.91000009e+00, 3.22000003e+00, 7.11100006e+01,
#        1.23209998e+03, 1.38909996e+00, 1.13089996e+02, 7.71300018e-01])

# %%
#inv_y[:,-8:].shape

# %%
inv_y = inv_y[:,-8:]

# %%
inv_y[:,0].shape
# Out:
# (2173,)

# %%
rmse = sqrt(mean_squared_error(inv_y[:,3], inv_yhat[:,3]))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE:
 20110426, 20110427, 20110428, 20110429, 20110502, 20110503, 20110504, 20110505, 20110506, 20110509, 20110510, 20110511, 20110512, 20110513, 20110516, 20110517, 20110518, 20110519, 20110520, 20110523, 20110524, 20110525, 20110526, 20110527, 20110531, 20110601, 20110602, 20110603, 20110606, 20110607, 20110608, 20110609, 20110610, 20110613, 20110614, 20110615, 20110616, 20110617, 20110620, 20110621, 20110622, 20110623, 20110624, 20110627, 20110628, 20110629, 20110630, 20110701, 20110705, 20110706, 20110707, 20110708, 20110711, 20110712, 20110713, 20110714, 20110715, 20110718, 20110719, 20110720, 20110721, 20110722, 20110725, 20110726, 20110727, 20110728, 20110729, 20110801, 20110802, 20110803, 20110804, 20110805, 20110808, 20110809, 20110810, 20110811, 20110812, 20110815, 20110816, 20110817, 20110818, 20110819, 20110822, 20110823, 20110824, 20110825, 20110826 ...

# %%
inv_yhat = concatenate((test_X[:, :], yhat), axis=1)

# %%
#normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
#convert data to become supervised 
look_back = 3
time_steps = 1
reframed = series_to_supervised(scaled, look_back, time_steps)
reframed.head()
# Out:
#    var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var5(t-3)  var6(t-3)  \
# 3   0.020057   0.808402   0.852144   0.070671   0.135459   0.408021
# 4   0.020781   0.809426   0.846501   0.069336   0.131714   0.411800
# 5   0.021516   0.800205   0.836343   0.070078   0.130130   0.413432
# 6   0.024084   0.781762   0.810384   0.070671   0.119474   0.425970
# 7   0.023943   0.786885   0.816027   0.070449   0.119778   0.422449
#
#    var7(t-3)  var8(t-3)  var1(t-2)  var2(t-2)  ...  var7(t-1)  var8(t-1)  \
# 3   0.760988   0.342629   0.020781   0.809426  ...   0.770729   0.352590
# 4   0.768948   0.346614   0.021516   0.800205  ...   0.802804   0.393284
# 5   0.770729   0.352590   0.024084   0.781762  ...   0.805417   0.416050
# 6   0.802804   0.393284   0.023943   0.786885  ...   0.803991   0.402390
# 7   0.805417   0.416050   0.024693   0.783811  ...   0.812307   0.398122
#
#     var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)   var7(t)  \
# 3  0.024084  0.781762  0.810384  0.070671  0.119474  0.425970  0.802804
# 4  0.023943  0.786885  0.816027  0.070449  0.119778  0.422449  0.805417
# 5  0.024693  0.783811  0.811512  0.070449  0.121971  0.427001  0.803991
# 6  0.024449  0.771516  0.803612  0.070300  0.120692  0.427001  0.812307
# 7  0.024350  0.769467  0.799097  0.070819  0.115759  0.422793  0.828344
#
#     var8(t)
# 3  0.393284
# 4  0.416050
# 5  0.402390
# 6  0.398122
# 7  0.403813
#
# [5 rows x 32 columns]

# %%
#splitting data 
values = reframed.values
n_train_hours = int(len(values) * 0.7)
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# %%
# split into input and outputs
#number_of_variables = 3
target = -1 * number_of_variables

train_X, train_y = train[:, :(look_back * number_of_variables)], train[:, target:]
test_X, test_y = test[:, :(look_back * number_of_variables) ], test[:, target:]

# %%
train_X
#test_X
# Out:
# array([[0.02005667, 0.80840164, 0.8521445 , ..., 0.4134317 , 0.7707295 ,
#         0.3525896 ],
#        [0.02078077, 0.80942625, 0.8465011 , ..., 0.42597038, 0.8028036 ,
#         0.39328384],
#        [0.02151594, 0.8002049 , 0.83634305, ..., 0.4224493 , 0.8054171 ,
#         0.41605008],
#        ...,
#        [0.2568392 , 0.07786885, 0.23702033, ..., 0.26923734, 0.2375862 ,
#         0.3747865 ],
#        [0.2656059 , 0.08299181, 0.26410836, ..., 0.28100306, 0.2375862 ,
#         0.3864541 ],
#        [0.2662967 , 0.0819672 , 0.25733638, ..., 0.29603225, 0.24530774,
#         0.41121233]], dtype=float32)

# %%
train_y
#test_y
# Out:
# array([[0.02408352, 0.7817623 , 0.81038374, ..., 0.42597038, 0.8028036 ,
#         0.39328384],
#        [0.02394314, 0.78688526, 0.8160271 , ..., 0.4224493 , 0.8054171 ,
#         0.41605008],
#        [0.02469309, 0.78381145, 0.8115125 , ..., 0.42700094, 0.8039915 ,
#         0.40239036],
#        ...,
#        [0.26150146, 0.07684426, 0.24717833, ..., 0.28100306, 0.2375862 ,
#         0.3864541 ],
#        [0.2654544 , 0.0819672 , 0.26523703, ..., 0.29603225, 0.24530774,
#         0.41121233],
#        [0.26457885, 0.11885247, 0.27878106, ..., 0.2930265 , 0.26680928,
#         0.4282868 ]], dtype=float32)

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
train_y = train_y.reshape((train_y.shape[0], 1, train_y.shape[1]))
test_y = test_y.reshape((test_y.shape[0], 1, test_y.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (5068, 1, 24) (5068, 1, 8) (2173, 1, 24) (2173, 1, 8)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, TimeDistributed
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
multi_model = Sequential()
multi_model.add(LSTM(
    input_shape=(train_X.shape[1],train_X.shape[2]),
    return_sequences=True, units=train_X.shape[1]))
#model.add(Dropout(0.2))
multi_model.add(LSTM(
    100,
    return_sequences=True))
#model.add(Dropout(0.2))
multi_model.add(TimeDistributed(Dense(number_of_variables)))
#model.add(Activation("linear"))
multi_model.compile(loss="mse", optimizer="rmsprop")
multi_history = multi_model.fit(train_X, train_y, epochs=30, batch_size=50, validation_data=(test_X, test_y), verbose=1, shuffle=False)
# Out:
# Train on 5068 samples, validate on 2173 samples
# Epoch 1/30
# 5068/5068 [==============================] - 3s 673us/step - loss: 0.0807 - val_loss: 0.0851
# Epoch 2/30
# 5068/5068 [==============================] - 1s 212us/step - loss: 0.0258 - val_loss: 0.0886
# Epoch 3/30
# 5068/5068 [==============================] - 1s 214us/step - loss: 0.0246 - val_loss: 0.0869
# Epoch 4/30
# 5068/5068 [==============================] - 1s 221us/step - loss: 0.0241 - val_loss: 0.0849
# Epoch 5/30
# 5068/5068 [==============================] - 1s 221us/step - loss: 0.0236 - val_loss: 0.0825
# Epoch 6/30
# 5068/5068 [==============================] - 1s 213us/step - loss: 0.0231 - val_loss: 0.0802
# Epoch 7/30
# 5068/5068 [==============================] - 1s 217us/step - loss: 0.0227 - val_loss: 0.0782
# Epoch 8/30
# 5068/5068 [==============================] - 1s 211us/step - loss: 0.0224 - val_loss: 0.0764
# Epoch 9/30
# 5068/5068 [==============================] - 1s 217us/step - loss: 0.0220 - val_loss: 0.0746
# Epoch 10/30
# 5068/5068 [==============================] - 1s 225us/step - loss: 0.0215 - val_loss: 0.0725
# Epoch 11/30
# 5068/5068 [==============================] - 1s 214us/step - loss: 0.0209 - val_loss: 0.0702
# Epoch 12/30
# 5068/5068 [==============================] - 1s 211us/step - loss: 0.0204 - val_loss: 0.0682
# Epoch 13/30
# 5068/5068 [==============================] - 1s 215us/step - loss: 0.0198 - val_loss: 0.0667
# Epoch 14/30
# 5068/5068 [==============================] - 1s 213us/step - loss: 0.0191 - val_loss: 0.0654
# Epoch 15/30
# 5068/5068 [==============================] - 1s 211us/step - loss: 0.0184 - val_loss: 0.0642
# Epoch 16/30
# 5068/5068 [==============================] - 1s 217us/step - loss: 0.0176 - val_loss: 0.0631
# Epoch 17/30
# 5068/5068 [==============================] - 1s 210us/step - loss: 0.0168 - val_loss: 0.0621
# Epoch 18/30
# 5068/5068 [==============================] - 1s 210us/step - loss: 0.0160 - val_loss: 0.0612
# Epoch 19/30
# 5068/5068 [==============================] - 1s 207us/step - loss: 0.0153 - val_loss: 0.0603
# Epoch 20/30
# 5068/5068 [==============================] - 1s 209us/step - loss: 0.0145 - val_loss: 0.0595
# Epoch 21/30
# 5068/5068 [==============================] - 1s 224us/step - loss: 0.0138 - val_loss: 0.0588
# Epoch 22/30
# 5068/5068 [==============================] - 1s 223us/step - loss: 0.0132 - val_loss: 0.0580
# Epoch 23/30
# 5068/5068 [==============================] - 1s 206us/step - loss: 0.0126 - val_loss: 0.0573
# Epoch 24/30
# 5068/5068 [==============================] - 1s 213us/step - loss: 0.0120 - val_loss: 0.0567
# Epoch 25/30
# 5068/5068 [==============================] - 1s 211us/step - loss: 0.0115 - val_loss: 0.0562
# Epoch 26/30
# 5068/5068 [==============================] - 1s 208us/step - loss: 0.0111 - val_loss: 0.0556
# Epoch 27/30
# 5068/5068 [==============================] - 1s 208us/step - loss: 0.0107 - val_loss: 0.0552
# Epoch 28/30
# 5068/5068 [==============================] - 1s 211us/step - loss: 0.0105 - val_loss: 0.0547
# Epoch 29/30
# 5068/5068 [==============================] - 1s 207us/step - loss: 0.0102 - val_loss: 0.0543
# Epoch 30/30
# 5068/5068 [==============================] - 1s 212us/step - loss: 0.0100 - val_loss: 0.0538

# %%
#plot result 
pyplot.plot(multi_history.history['loss'], label='multi_train')
pyplot.plot(multi_history.history['val_loss'], label='multi_test')
pyplot.legend()
pyplot.show()

# %%
#plot prediction
yhat = multi_model.predict(test_X)
#yhat
pyplot.plot(yhat[:,0][:,0], label='predict')
pyplot.plot(test_y[:,0][:,0], label='true')
pyplot.legend()
pyplot.show()

# %%
#yhat[:,0][:,0]

# %%
#DON't LOOK BELOW

test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-367ee3ebe101> in <module>
#       3 test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
#       4 # invert scaling for forecast
# ----> 5 inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
#       6 inv_yhat = scaler.inverse_transform(inv_yhat)
#       7 inv_yhat = inv_yhat[:,0]
#
# ValueError: all the input arrays must have same number of dimensions

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.007

# %%
actual_chart = go.Scatter(x=predictDates, y=inv_y, name= 'Actual Price')
multi_predict_chart = go.Scatter(x=predictDates, y=inv_yhat, name= 'Multi Predict Price')
predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, name= 'Predict Price')
py.iplot([predict_chart, multi_predict_chart, actual_chart])
# Out:
# <div id="64d4674e-6743-414e-b717-da3afd4a4a74" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("64d4674e-6743-414e-b717-da3afd4a4a74", [{"name": "Predict Price", "x": [20090529, 20090601, 20090602, 20090603, 20090604, 20090605, 20090608, 20090609, 20090610, 20090611, 20090612, 20090615, 20090616, 20090617, 20090618, 20090619, 20090622, 20090623, 20090624, 20090625, 20090626, 20090629, 20090630, 20090701, 20090702, 20090706, 20090707, 20090708, 20090709, 20090710, 20090713, 20090714, 20090715, 20090716, 20090717, 20090720, 20090721, 20090722, 20090723, 20090724, 20090727, 20090728, 20090729, 20090730, 20090731, 20090803, 20090804