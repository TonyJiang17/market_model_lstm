# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import plotly.offline as py
import plotly.graph_objs as go
import numpy as np
import seaborn as sns
py.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
data = pd.read_csv(filepath_or_buffer="./Data/clean_data.csv", index_col="date")

# %%
data.head()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU  spindx GOLDPMGBD228NLBM  exalus  \
# date
# 19870520       8.05        8.92        18.63  278.21          475.250  1.3820
# 19870521       8.06        8.87        18.45  280.17          469.100  1.3864
# 19870522       7.97        8.78        18.55  282.16          466.500  1.3883
# 19870526       7.79        8.55        18.63  289.11          449.000  1.4029
# 19870527       7.84        8.60        18.60  288.73          449.500  1.3988
#
#           exjpus  exukus
# date
# 19870520  139.78  0.5942
# 19870521  140.45  0.5956
# 19870522  140.60  0.5977
# 19870526  143.30  0.6120
# 19870527  143.52  0.6200

# %%
data.tail()
# Out:
#           TCMNOM_Y2  TCMNOM_Y10 DCOILBRENTEU   spindx GOLDPMGBD228NLBM  \
# date
# 20181029       2.81        3.08        77.56  2641.25          1230.80
# 20181030       2.84        3.12        75.68  2682.63          1225.40
# 20181031       2.87        3.15        74.84  2711.74          1214.95
# 20181101       2.84        3.14        71.25  2740.37          1231.15
# 20181102       2.91        3.22        71.11  2723.06          1232.10
#
#           exalus  exjpus  exukus
# date
# 20181029  1.4136  112.49  0.7808
# 20181030  1.4061  112.76  0.7855
# 20181031  1.4104  112.86  0.7825
# 20181101  1.3910  112.79  0.7708
# 20181102  1.3891  113.09  0.7713

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7931 non-null object
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7931 non-null object
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 557.6+ KB

# %%
#data.DCOILBRENTEU.to_numericd
#data.GOLDPMGBD228NLBM = data.GOLDPMGBD228NLBM.astype(dtype = np.float64)
#data['GOLDPMGBD228NLBM'][0]
data = data.apply(pd.to_numeric, errors = "coerce")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7931 entries, 19870520 to 20181102
# Data columns (total 8 columns):
# TCMNOM_Y2           7931 non-null float64
# TCMNOM_Y10          7931 non-null float64
# DCOILBRENTEU        7858 non-null float64
# spindx              7931 non-null float64
# GOLDPMGBD228NLBM    7734 non-null float64
# exalus              7931 non-null float64
# exjpus              7931 non-null float64
# exukus              7931 non-null float64
# dtypes: float64(8)
# memory usage: 557.6 KB

# %%
btc_trace = go.Scatter(x=data.index, y=data['exukus'], name= 'exu')
py.iplot([btc_trace])
# Out:
# <div id="705f31b5-4547-4b27-955f-62bbc31118e5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("705f31b5-4547-4b27-955f-62bbc31118e5", [{"name": "exu", "x": [19870520, 19870521, 19870522, 19870526, 19870527, 19870528, 19870529, 19870601, 19870602, 19870603, 19870604, 19870605, 19870608, 19870609, 19870610, 19870611, 19870612, 19870615, 19870616, 19870617, 19870618, 19870619, 19870622, 19870623, 19870624, 19870625, 19870626, 19870629, 19870630, 19870701, 19870702, 19870706, 19870707, 19870708, 19870709, 19870710, 19870713, 19870714, 19870715, 19870716, 19870717, 19870720, 19870721, 19870722, 19870723, 19870724, 19870727, 19870728, 19870729, 19870730, 19870731, 19870803, 19870804, 19870805, 19870806, 19870807, 19870810, 19870811, 19870812, 19870813, 19870814, 19870817, 19870818, 19870819, 19870820, 19870821, 19870824, 19870825, 19870826, 19870827, 19870828, 19870831, 19870901, 19870902, 19870903, 19870904, 19870908, 19870909, 19870910, 19870911, 19870914, 19870915, 19870916, 19870917, 19870918, 19870921, 19870922, 19870923, 19870924, 19870925, 19870928, 19870929, 19870930, 19871001, 19871002, 19871005, 19871006, 19871007, 19871008, 19871009, 19871012, 19871013, 19871014, 19871015, 19871016, 19871019, 19871020, 19871021, 19871022, 19871023, 19871026, 19871027, 19871028, 19871029, 19871030, 19871102, 19871103, 19871104, 19871105, 19871106, 19871109, 19871110, 19871111, 19871112, 19871113, 19871116, 19871117, 19871118, 19871119, 19871120, 19871123, 19871124, 19871125, 19871127, 19871130, 19871201, 19871202, 19871203, 19871204, 19871207, 19871208, 19871209, 19871210, 19871211, 19871214, 19871215, 19871216, 19871217, 19871218, 19871221, 19871222, 19871223, 19871224, 19871228, 19871229, 19871230, 19871231, 19880104, 19880105, 19880106, 19880107, 19880108, 19880111, 19880112, 19880113, 19880114, 19880115, 19880118, 19880119, 19880120, 19880121, 19880122, 19880125, 19880126, 19880127, 19880128, 19880129, 19880201, 19880202, 19880203, 19880204, 19880205, 19880208, 19880209, 19880210, 19880211, 19880212, 19880216, 19880217, 19880218, 19880219, 19880222, 19880223, 19880224, 19880225, 19880226, 19880229, 19880301, 19880302, 19880303, 19880304, 19880307, 19880308, 19880309, 19880310, 19880311, 19880314, 19880315, 19880316, 19880317, 19880318, 19880321, 19880322, 19880323, 19880324, 19880325, 19880328, 19880329, 19880330, 19880331, 19880404, 19880405, 19880406, 19880407, 19880408, 19880411, 19880412, 19880413, 19880414, 19880415, 19880418, 19880419, 19880420, 19880421, 19880422, 19880425, 19880426, 19880427, 19880428, 19880429, 19880502, 19880503, 19880504, 19880505, 19880506, 19880509, 19880510, 19880511, 19880512, 19880513, 19880516, 19880517, 19880518, 19880519, 19880520, 19880523, 19880524, 19880525, 19880526, 19880527, 19880531, 19880601, 19880602, 19880603, 19880606, 19880607, 19880608, 19880609, 19880610, 19880613, 19880614, 19880615, 19880616, 19880617, 19880620, 19880621, 19880622, 19880623, 19880624, 19880627, 19880628, 19880629, 19880630, 19880701, 19880705, 19880706, 19880707, 19880708, 19880711, 19880712, 19880713, 19880714, 19880715, 19880718, 19880719, 19880720, 19880721, 19880722, 19880725, 19880726, 19880727, 19880728, 19880729, 19880801, 19880802, 19880803, 19880804, 19880805, 19880808, 19880809, 19880810, 19880811, 19880812, 19880815, 19880816, 19880817, 19880818, 19880819, 19880822, 19880823, 19880824, 19880825, 19880826, 19880829, 19880830, 19880831, 19880901, 19880902, 19880906, 19880907, 19880908, 19880909, 19880912, 19880913, 19880914, 19880915, 19880916, 19880919, 19880920, 19880921, 19880922, 19880923, 19880926, 19880927, 19880928, 19880929, 19880930, 19881003, 19881004, 19881005, 19881006, 19881007, 19881010, 19881011, 19881012, 19881013, 19881014, 19881017, 19881018, 19881019, 19881020, 19881021, 19881024, 19881025, 19881026, 1988 ...

# %%
data['exukus'].replace(0, np.nan, inplace=True)
data['exukus'].fillna(method='ffill', inplace=True)

# %%
#reshaping prediction value into value range -1 to 1
from sklearn.preprocessing import MinMaxScaler

# %%
values = data['exukus'].values.reshape(-1,1)
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
values
# Out:
# array([[0.5942],
#        [0.5956],
#        [0.5977],
#        ...,
#        [0.7825],
#        [0.7708],
#        [0.7713]], dtype=float32)

# %%
scaled
# Out:
# array([[0.34262943],
#        [0.34661353],
#        [0.3525896 ],
#        ...,
#        [0.8784859 ],
#        [0.8451905 ],
#        [0.8466134 ]], dtype=float32)

# %%
#split dataset into train and test, 70% train 30% test

# %%
train_size = int(len(scaled) * 0.7)
test_size = len(scaled) - train_size
train, test = scaled[0:train_size,:], scaled[train_size:len(scaled),:]
print(len(train), len(test))
# Out:
# 5551 2380

# %%
#function that convert the dataset to be 3d
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    print(len(dataY))
    return np.array(dataX), np.array(dataY)

# %%
look_back = 3 #use 3 previous days to predict the next day
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# Out:
# 5548
# 2377

# %%
trainX
# Out:
# array([[0.34262943, 0.34661353, 0.3525896 ],
#        [0.34661353, 0.3525896 , 0.39328384],
#        [0.3525896 , 0.39328384, 0.41605008],
#        ...,
#        [0.52105856, 0.51052916, 0.4874786 ],
#        [0.51052916, 0.4874786 , 0.46784282],
#        [0.4874786 , 0.46784282, 0.45702899]], dtype=float32)

# %%
trainY
# Out:
# array([0.39328384, 0.41605008, 0.40239036, ..., 0.46784282, 0.45702899,
#        0.44223094], dtype=float32)

# %%
#reshaping data into 3-D
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
trainX
# Out:
# array([[[0.34262943, 0.34661353, 0.3525896 ]],
#
#        [[0.34661353, 0.3525896 , 0.39328384]],
#
#        [[0.3525896 , 0.39328384, 0.41605008]],
#
#        ...,
#
#        [[0.52105856, 0.51052916, 0.4874786 ]],
#
#        [[0.51052916, 0.4874786 , 0.46784282]],
#
#        [[0.4874786 , 0.46784282, 0.45702899]]], dtype=float32)

# %%
#run the model
model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=50, batch_size=100, validation_data=(testX, testY), verbose=1, shuffle=False)
# Out:
# Train on 5548 samples, validate on 2377 samples
# Epoch 1/50
# 5548/5548 [==============================] - 2s 291us/step - loss: 0.1824 - val_loss: 0.0439
# Epoch 2/50
# 5548/5548 [==============================] - 0s 71us/step - loss: 0.0542 - val_loss: 0.0567
# Epoch 3/50
# 5548/5548 [==============================] - 0s 70us/step - loss: 0.0304 - val_loss: 0.0618
# Epoch 4/50
# 5548/5548 [==============================] - 0s 71us/step - loss: 0.0155 - val_loss: 0.0601
# Epoch 5/50
# 5548/5548 [==============================] - 0s 71us/step - loss: 0.0140 - val_loss: 0.0242
# Epoch 6/50
# 5548/5548 [==============================] - 0s 71us/step - loss: 0.0127 - val_loss: 0.0182
# Epoch 7/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0126 - val_loss: 0.0175
# Epoch 8/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0119 - val_loss: 0.0167
# Epoch 9/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0122 - val_loss: 0.0174
# Epoch 10/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0120 - val_loss: 0.0170
# Epoch 11/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0119 - val_loss: 0.0169
# Epoch 12/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0118 - val_loss: 0.0170
# Epoch 13/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0118 - val_loss: 0.0171
# Epoch 14/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0118 - val_loss: 0.0169
# Epoch 15/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0116 - val_loss: 0.0169
# Epoch 16/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0114 - val_loss: 0.0163
# Epoch 17/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0112 - val_loss: 0.0157
# Epoch 18/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0110 - val_loss: 0.0149
# Epoch 19/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0108 - val_loss: 0.0148
# Epoch 20/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0106 - val_loss: 0.0137
# Epoch 21/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0105 - val_loss: 0.0135
# Epoch 22/50
# 5548/5548 [==============================] - 0s 68us/step - loss: 0.0103 - val_loss: 0.0130
# Epoch 23/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0102 - val_loss: 0.0125
# Epoch 24/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0101 - val_loss: 0.0121
# Epoch 25/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0099 - val_loss: 0.0114
# Epoch 26/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0099 - val_loss: 0.0111
# Epoch 27/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0098 - val_loss: 0.0107
# Epoch 28/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0097 - val_loss: 0.0104
# Epoch 29/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0096 - val_loss: 0.0102
# Epoch 30/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0095 - val_loss: 0.0102
# Epoch 31/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0094 - val_loss: 0.0101
# Epoch 32/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 33/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 34/50
# 5548/5548 [==============================] - 0s 64us/step - loss: 0.0092 - val_loss: 0.0101
# Epoch 35/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0092 - val_loss: 0.0097
# Epoch 36/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0091 - val_loss: 0.0100
# Epoch 37/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0091 - val_loss: 0.0099
# Epoch 38/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0091 - val_loss: 0.0101
# Epoch 39/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0091 - val_loss: 0.0101
# Epoch 40/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0091 - val_loss: 0.0101
# Epoch 41/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 42/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0090 - val_loss: 0.0103
# Epoch 43/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0090 - val_loss: 0.0106
# Epoch 44/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0089 - val_loss: 0.0107
# Epoch 45/50
# 5548/5548 [==============================] - 0s 65us/step - loss: 0.0090 - val_loss: 0.0118
# Epoch 46/50
# 5548/5548 [==============================] - 0s 67us/step - loss: 0.0090 - val_loss: 0.0127
# Epoch 47/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0091 - val_loss: 0.0137
# Epoch 48/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0091 - val_loss: 0.0145
# Epoch 49/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0092 - val_loss: 0.0147
# Epoch 50/50
# 5548/5548 [==============================] - 0s 66us/step - loss: 0.0092 - val_loss: 0.0146

# %%
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
yhat = model.predict(testX)
pyplot.plot(yhat, label='predict')
pyplot.plot(testY, label='true')
pyplot.legend()
pyplot.show()

# %%
#inverse y back to values
yhat_inverse = scaler.inverse_transform(yhat.reshape(-1, 1))
testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))

# %%
rmse = sqrt(mean_squared_error(testY_inverse, yhat_inverse))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.007

# %%
pyplot.plot(yhat_inverse, label='predict')
pyplot.plot(testY_inverse, label='actual', alpha=0.5)
pyplot.legend()
pyplot.show()

# %%
#convert back to normal 
predictDates = data.tail(len(testX)).index
testY_reshape = testY_inverse.reshape(len(testY_inverse))
yhat_reshape = yhat_inverse.reshape(len(yhat_inverse))

# %%
actual_chart = go.Scatter(x=predictDates, y=testY_reshape, name= 'Actual Price')
predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, name= 'Predict Price')
py.iplot([predict_chart, actual_chart])
# Out:
# <div id="2232f268-01b3-4c9a-9399-51f97c1a72c3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2232f268-01b3-4c9a-9399-51f97c1a72c3", [{"name": "Predict Price", "x": [20090529, 20090601, 20090602, 20090603, 20090604, 20090605, 20090608, 20090609, 20090610, 20090611, 20090612, 20090615, 20090616, 20090617, 20090618, 20090619, 20090622, 20090623, 20090624, 20090625, 20090626, 20090629, 20090630, 20090701, 20090702, 20090706, 20090707, 20090708, 20090709, 20090710, 20090713, 20090714, 20090715, 20090716, 20090717, 20090720, 20090721, 20090722, 20090723, 20090724, 20090727, 20090728, 20090729, 20090730, 20090731, 20090803, 20090804, 20090805, 20090806, 20090807, 20090810, 20090811, 20090812, 20090813, 20090814, 20090817, 20090818, 20090819, 20090820, 20090821, 20090824, 20090825, 20090826, 20090827, 20090828, 20090831, 20090901, 20090902, 20090903, 20090904, 20090908, 20090909, 20090910, 20090911, 20090914, 20090915, 20090916, 20090917, 20090918, 20090921, 20090922, 20090923, 20090924, 20090925, 20090928, 20090929, 20090930, 20091001, 20091002, 20091005, 20091006, 20091007, 20091008, 20091009, 20091012, 20091013, 20091014, 20091015, 20091016, 20091019, 20091020, 20091021, 20091022, 20091023, 20091026, 20091027, 20091028, 20091029, 20091030, 20091102, 20091103, 20091104, 20091105, 20091106, 20091109, 20091110, 20091111, 20091112, 20091113, 20091116, 20091117, 20091118, 20091119, 20091120, 20091123, 20091124, 20091125, 20091127, 20091130, 20091201, 20091202, 20091203, 20091204, 20091207, 20091208, 20091209, 20091210, 20091211, 20091214, 20091215, 20091216, 20091217, 20091218, 20091221, 20091222, 20091223, 20091224, 20091228, 20091229, 20091230, 20091231, 20100104, 20100105, 20100106, 20100107, 20100108, 20100111, 20100112, 20100113, 20100114, 20100115, 20100119, 20100120, 20100121, 20100122, 20100125, 20100126, 20100127, 20100128, 20100129, 20100201, 20100202, 20100203, 20100204, 20100205, 20100208, 20100209, 20100210, 20100211, 20100212, 20100216, 20100217, 20100218, 20100219, 20100222, 20100223, 20100224, 20100225, 20100226, 20100301, 20100302, 20100303, 20100304, 20100305, 20100308, 20100309, 20100310, 20100311, 20100312, 20100315, 20100316, 20100317, 20100318, 20100319, 20100322, 20100323, 20100324, 20100325, 20100326, 20100329, 20100330, 20100331, 20100401, 20100405, 20100406, 20100407, 20100408, 20100409, 20100412, 20100413, 20100414, 20100415, 20100416, 20100419, 20100420, 20100421, 20100422, 20100423, 20100426, 20100427, 20100428, 20100429, 20100430, 20100503, 20100504, 20100505, 20100506, 20100507, 20100510, 20100511, 20100512, 20100513, 20100514, 20100517, 20100518, 20100519, 20100520, 20100521, 20100524, 20100525, 20100526, 20100527, 20100528, 20100601, 20100602, 20100603, 20100604, 20100607, 20100608, 20100609, 20100610, 20100611, 20100614, 20100615, 20100616, 20100617, 20100618, 20100621, 20100622, 20100623, 20100624, 20100625, 20100628, 20100629, 20100630, 20100701, 20100702, 20100706, 20100707, 20100708, 20100709, 20100712, 20100713, 20100714, 20100715, 20100716, 20100719, 20100720, 20100721, 20100722, 20100723, 20100726, 20100727, 20100728, 20100729, 20100730, 20100802, 20100803, 20100804, 20100805, 20100806, 20100809, 20100810, 20100811, 20100812, 20100813, 20100816, 20100817, 20100818, 20100819, 20100820, 20100823, 20100824, 20100825, 20100826, 20100827, 20100830, 20100831, 20100901, 20100902, 20100903, 20100907, 20100908, 20100909, 20100910, 20100913, 20100914, 20100915, 20100916, 20100917, 20100920, 20100921, 20100922, 20100923, 20100924, 20100927, 20100928, 20100929, 20100930, 20101001, 20101004, 20101005, 20101006, 20101007, 20101008, 20101011, 20101012, 20101013, 20101014, 20101015, 20101018, 20101019, 20101020, 20101021, 20101022, 20101025, 20101026, 20101027, 20101028, 20101029, 20101101, 20101102, 20101103, 20101104, 2010 ...

# %%
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.1, vmin=0)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
data.columns
#values = data[['exukus'] + ['Volume (BTC)'] + ['Volume (Currency)']].values
#values = values.astype('float32')
# Out:
# Index(['TCMNOM_Y2', 'TCMNOM_Y10', 'DCOILBRENTEU', 'spindx', 'GOLDPMGBD228NLBM',
#        'exalus', 'exjpus', 'exukus'],
#       dtype='object')

# %%
number_of_variables = 8
values = data[['spindx'] + ['TCMNOM_Y2'] + ['TCMNOM_Y10'] + ['DCOILBRENTEU'] + ['GOLDPMGBD228NLBM'] + ['exalus'] + ['exjpus'] + ['exukus']].values
values = values.astype('float32')

# %%
#normalize features
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaled = scaler.fit_transform(values)

# %%
values
# Out:
# array([[2.78210e+02, 8.05000e+00, 8.92000e+00, ..., 1.38200e+00,
#         1.39780e+02, 5.94200e-01],
#        [2.80170e+02, 8.06000e+00, 8.87000e+00, ..., 1.38640e+00,
#         1.40450e+02, 5.95600e-01],
#        [2.82160e+02, 7.97000e+00, 8.78000e+00, ..., 1.38830e+00,
#         1.40600e+02, 5.97700e-01],
#        ...,
#        [2.71174e+03, 2.87000e+00, 3.15000e+00, ..., 1.41040e+00,
#         1.12860e+02, 7.82500e-01],
#        [2.74037e+03, 2.84000e+00, 3.14000e+00, ..., 1.39100e+00,
#         1.12790e+02, 7.70800e-01],
#        [2.72306e+03, 2.91000e+00, 3.22000e+00, ..., 1.38910e+00,
#         1.13090e+02, 7.71300e-01]], dtype=float32)

# %%
#convert data to become supervised 
look_back = 10
time_steps = 5
reframed = series_to_supervised(values, look_back, time_steps)
reframed
# Out:
#         var1(t-5)  var2(t-5)  var3(t-5)  var4(t-5)    var5(t-5)  var6(t-5)  \
# 5      278.209991       8.05       8.92  18.629999   475.250000     1.3820
# 6      280.170013       8.06       8.87  18.450001   469.100006     1.3864
# 7      282.160004       7.97       8.78  18.549999   466.500000     1.3883
# 8      289.109985       7.79       8.55  18.629999   449.000000     1.4029
# 9      288.730011       7.84       8.60  18.600000   449.500000     1.3988
# 10     290.760010       7.81       8.56  18.600000   453.100006     1.4041
# 11     290.100006       7.69       8.49  18.580000   451.000000     1.4041
# 12     289.829987       7.67       8.45  18.650000   442.899994     1.3992
# 23     304.760010       7.47       8.28  18.900000   452.750000     1.3904
# 24     304.809998       7.42       8.23  19.030001   451.250000     1.3829
# 25     305.690002       7.44       8.27  19.049999   452.200012     1.3850
# 26     306.970001       7.45       8.30  19.049999   449.000000     1.3868
# 27     309.649994       7.42       8.23  19.100000   438.000000     1.3864
# 28     308.429993       7.45       8.23  18.900000   440.200012     1.3957
# 29     306.859985       7.54       8.31  18.750000   441.750000     1.3941
# 30     308.959991       7.47       8.25  18.700001   440.500000     1.3885
# 31     307.160004       7.56       8.37  19.080000   444.100006     1.3906
# 32     307.899994       7.48       8.34  19.150000   449.750000     1.3873
# 33     304.000000       7.48       8.38  19.080000   447.299988     1.3872
# 34     302.940002       7.44       8.36  18.980000   445.750000     1.3872
# 35     305.630005       7.38       8.30  19.250000   446.250000     1.3889
# 36     304.920013       7.38       8.29  19.480000   443.350006     1.4043
# 37     307.399994       7.36       8.28  19.500000   444.500000     1.4286
# 38     308.290009       7.35       8.32  19.480000   446.399994     1.4166
# 39     307.519989       7.38       8.37  19.680000   444.100006     1.4090
# 40     308.390015       7.32       8.32  19.730000   444.750000     1.4130
# 41     307.630005       7.36       8.38  19.830000   446.500000     1.4134
# 42     310.679993       7.32       8.33  19.879999   447.000000     1.4144
# 43     310.420013       7.37       8.43  20.280001   452.700012     1.4085
# 44     312.700012       7.34       8.41  20.400000   453.750000     1.4053
# ...           ...        ...        ...        ...          ...        ...
# 7897  2887.889893       2.76       2.98  78.220001  1189.849976     1.4071
# 7898  2888.919922       2.74       2.97  80.019997  1195.599976     1.3965
# 7899  2904.179932       2.76       2.97  77.660004  1209.800049     1.3904
# 7900  2904.979980       2.78       2.99  77.870003  1201.949951     1.3931
# 7901  2888.800049       2.78       2.99  78.220001  1201.900024     1.3916
# 7902  2904.310059       2.81       3.05  79.250000  1200.199951     1.3850
# 7903  2907.949951       2.81       3.08  79.430000  1203.300049     1.3749
# 7904  2930.750000       2.81       3.07  79.029999  1208.349976     1.3744
# 7905  2929.669922       2.81       3.07  78.900002  1198.699951     1.3740
# 7906  2919.370117       2.83       3.08  80.889999  1202.750000     1.3768
# 7907  2915.560059       2.83       3.10  82.209999  1201.900024     1.3791
# 7908  2905.969971       2.83       3.06  81.870003  1194.250000     1.3774
# 7909  2914.000000       2.83       3.06  81.540001  1185.400024     1.3854
# 7910  2913.979980       2.81       3.05  82.720001  1187.250000     1.3816
# 7911  2924.590088       2.82       3.09  84.940002  1189.349976     1.3845
# 7912  2923.429932       2.82       3.05  85.629997  1204.699951     1.3891
# 7913  2925.510010       2.85       3.15  85.449997  1201.199951     1.4010
# 7914  2901.610107       2.87       3.19  86.070000  1203.449951     1.4128
# 7915  2885.570068       2.88       3.23  85.120003  1203.800049     1.4188
# 7916  2884.429932       2.88       3.22  84.220001  1186.949951     1.4144
# 7917  2880.340088       2.88       3.21  85.160004  1185.550049     1.4100
# 7918  2785.679932       2.88       3.22  83.820000  1188.599976     1.4085
# 7919  2728.370117       2.85       3.14  81.349998  1205.550049     1.4061
# 7920  2767.129883       2.85       3.15  80.709999  1219.750000     1.4053
# 7921  2750.790039       2.85       3.16  80.910004  1229.949951     1.4002
# 7922  2809.919922       2.87       3.16  80.529999  1230.699951     1.4006
# 7923  2809.209961       2.89       3.19  79.910004  1229.050049     1.4025
# 7924  2768.780029       2.87       3.17  80.300003  1223.000000     1.4049
# 7925  2767.780029       2.92       3.20  80.379997  1227.849976     1.4021
# 7926  2755.879883       2.92       3.20  80.449997  1222.300049     1.4112
#
#        var7(t-5)  var8(t-5)    var1(t-4)  var2(t-4)  ...   var7(t+3)  \
# 5     139.779999     0.5942   280.170013       8.06  ...  142.250000
# 6     140.449997     0.5956   282.160004       7.97  ...  142.800003
# 7     140.600006     0.5977   289.109985       7.79  ...  144.300003
# 8     143.300003     0.6120   288.730011       7.84  ...  143.800003
# 9     143.520004     0.6200   290.760010       7.81  ...  143.449997
# 10    143.399994     0.6152   290.100006       7.69  ...  142.500000
# 11    144.100006     0.6137   289.829987       7.67  ...  142.449997
# 12    145.449997     0.6157   288.459991       7.85  ...  142.550003
# 23    144.449997     0.6120   304.809998       7.42  ...  146.300003
# 24    144.649994     0.6119   305.690002       7.44  ...  146.699997
# 25    144.600006     0.6136   306.970001       7.45  ...  146.800003
# 26    145.050003     0.6188   309.649994       7.42  ...  146.850006
# 27    145.899994     0.6270   308.429993       7.45  ...  147.300003
# 28    146.029999     0.6254   306.859985       7.54  ...  149.130005
# 29    145.080002     0.6165   308.959991       7.47  ...  149.699997
# 30    146.330002     0.6203   307.160004       7.56  ...  150.570007
# 31    146.300003     0.6209   307.899994       7.48  ...  149.979996
# 32    146.699997     0.6247   304.000000       7.48  ...  150.649994
# 33    146.800003     0.6200   302.940002       7.44  ...  150.979996
# 34    146.850006     0.6190   305.630005       7.38  ...  151.080002
# 35    147.300003     0.6190   304.920013       7.38  ...  148.649994
# 36    149.130005     0.6179   307.399994       7.36  ...  150.550003
# 37    149.699997     0.6173   308.290009       7.35  ...  152.759995
# 38    150.570007     0.6181   307.519989       7.38  ...  152.850006
# 39    149.979996     0.6182   308.390015       7.32  ...  152.660004
# 40    150.649994     0.6198   307.630005       7.36  ...  152.339996
# 41    150.979996     0.6182   310.679993       7.32  ...  150.779999
# 42    151.080002     0.6208   310.420013       7.37  ...  149.949997
# 43    148.649994     0.6129   312.700012       7.34  ...  150.449997
# 44    150.550003     0.6133   314.589996       7.34  ...  150.380005
# ...          ...        ...          ...        ...  ...         ...
# 7897  111.540001     0.7683  2888.919922       2.74  ...  112.620003
# 7898  111.290001     0.7675  2904.179932       2.76  ...  112.620003
# 7899  111.919998     0.7631  2904.979980       2.78  ...  112.879997
# 7900  112.089996     0.7643  2888.800049       2.78  ...  112.919998
# 7901  111.970001     0.7607  2904.310059       2.81  ...  113.379997
# 7902  112.300003     0.7600  2907.949951       2.81  ...  113.480003
# 7903  112.209999     0.7598  2930.750000       2.81  ...  113.959999
# 7904  112.580002     0.7555  2929.669922       2.81  ...  113.660004
# 7905  112.620003     0.7653  2919.370117       2.83  ...  114.190002
# 7906  112.620003     0.7617  2915.560059       2.83  ...  113.790001
# 7907  112.879997     0.7598  2905.969971       2.83  ...  113.559998
# 7908  112.919998     0.7586  2914.000000       2.83  ...  113.345001
# 7909  113.379997     0.7631  2913.979980       2.81  ...  113.129997
# 7910  113.480003     0.7661  2924.590088       2.82  ...  112.709999
# 7911  113.959999     0.7673  2923.429932       2.82  ...  112.260002
# 7912  113.660004     0.7702  2925.510010       2.85  ...  112.019997
# 7913  114.190002     0.7696  2901.610107       2.87  ...  111.820000
# 7914  113.790001     0.7684  2885.570068       2.88  ...  112.160004
# 7915  113.559998     0.7633  2884.429932       2.88  ...  112.209999
# 7916  113.345001     0.7622  2880.340088       2.88  ...  112.110001
# 7917  113.129997     0.7611  2785.679932       2.88  ...  112.519997
# 7918  112.709999     0.7572  2728.370117       2.85  ...  112.779999
# 7919  112.260002     0.7580  2767.129883       2.85  ...  112.120003
# 7920  112.019997     0.7602  2750.790039       2.85  ...  112.580002
# 7921  111.820000     0.7594  2809.919922       2.87  ...  112.540001
# 7922  112.160004     0.7570  2809.209961       2.89  ...  111.650002
# 7923  112.209999     0.7612  2768.780029       2.87  ...  112.489998
# 7924  112.110001     0.7656  2767.780029       2.92  ...  112.760002
# 7925  112.519997     0.7666  2755.879883       2.92  ...  112.860001
# 7926  112.779999     0.7708  2740.689941       2.89  ...  112.790001
#
#       var8(t+3)    var1(t+4)  var2(t+4)  var3(t+4)  var4(t+4)    var5(t+4)  \
# 5        0.6085   293.470001       7.78       8.64  18.750000   453.000000
# 6        0.6086   295.089996       7.76       8.58  18.780001   452.750000
# 7        0.6161   293.450012       7.66       8.50  18.650000   453.500000
# 8        0.6131   296.720001       7.68       8.53  18.750000   456.549988
# 9        0.6103   297.279999       7.71       8.56  18.780001   452.649994
# 10       0.6020   297.470001       7.68       8.56  18.780001   455.649994
# 11       0.6030   298.730011       7.66       8.52  18.680000   457.000000
# 12       0.6019   301.619995       7.51       8.32  18.780001   455.450012
# 23       0.6209   307.899994       7.48       8.34  19.150000   449.750000
# 24       0.6247   304.000000       7.48       8.38  19.080000   447.299988
# 25       0.6200   302.940002       7.44       8.36  18.980000   445.750000
# 26       0.6190   305.630005       7.38       8.30  19.250000   446.250000
# 27       0.6190   304.920013       7.38       8.29  19.480000   443.350006
# 28       0.6179   307.399994       7.36       8.28  19.500000   444.500000
# 29       0.6173   308.290009       7.35       8.32  19.480000   446.399994
# 30       0.6181   307.519989       7.38       8.37  19.680000   444.100006
# 31       0.6182   308.390015       7.32       8.32  19.730000   444.750000
# 32       0.6198   307.630005       7.36       8.38  19.830000   446.500000
# 33       0.6182   310.679993       7.32       8.33  19.879999   447.000000
# 34       0.6208   310.420013       7.37       8.43  20.280001   452.700012
# 35       0.6129   312.700012       7.34       8.41  20.400000   453.750000
# 36       0.6133   314.589996       7.34       8.36  20.629999   450.600006
# 37       0.6221   311.390015       7.38       8.41  20.549999   450.899994
# 38       0.6243   308.549988       7.45       8.49  20.350000   452.399994
# 39       0.6268   308.470001       7.47       8.54  20.330000   454.899994
# 40       0.6270   307.809998       7.46       8.56  20.150000   453.950012
# 41       0.6236   309.269989       7.53       8.58  19.580000   453.299988
# 42       0.6238   310.649994       7.59       8.60  19.299999   453.149994
# 43       0.6260   312.329987       7.61       8.62  19.780001   456.149994
# 44       0.6256   315.649994       7.64       8.61  19.980000   457.750000
# ...         ...          ...        ...        ...        ...          ...
# 7897     0.7653  2919.370117       2.83       3.08  80.889999  1202.750000
# 7898     0.7617  2915.560059       2.83       3.10  82.209999  1201.900024
# 7899     0.7598  2905.969971       2.83       3.06  81.870003  1194.250000
# 7900     0.7586  2914.000000       2.83       3.06  81.540001  1185.400024
# 7901     0.7631  2913.979980       2.81       3.05  82.720001  1187.250000
# 7902     0.7661  2924.590088       2.82       3.09  84.940002  1189.349976
# 7903     0.7673  2923.429932       2.82       3.05  85.629997  1204.699951
# 7904     0.7702  2925.510010       2.85       3.15  85.449997  1201.199951
# 7905     0.7696  2901.610107       2.87       3.19  86.070000  1203.449951
# 7906     0.7684  2885.570068       2.88       3.23  85.120003  1203.800049
# 7907     0.7633  2884.429932       2.88       3.22  84.220001  1186.949951
# 7908     0.7622  2880.340088       2.88       3.21  85.160004  1185.550049
# 7909     0.7611  2785.679932       2.88       3.22  83.820000  1188.599976
# 7910     0.7572  2728.370117       2.85       3.14  81.349998  1205.550049
# 7911     0.7580  2767.129883       2.85       3.15  80.709999  1219.750000
# 7912     0.7602  2750.790039       2.85       3.16  80.910004  1229.949951
# 7913     0.7594  2809.919922       2.87       3.16  80.529999  1230.699951
# 7914     0.7570  2809.209961       2.89       3.19  79.910004  1229.050049
# 7915     0.7612  2768.780029       2.87       3.17  80.300003  1223.000000
# 7916     0.7656  2767.780029       2.92       3.20  80.379997  1227.849976
# 7917     0.7666  2755.879883       2.92       3.20  80.449997  1222.300049
# 7918     0.7708  2740.689941       2.89       3.17  78.669998  1235.949951
# 7919     0.7703  2656.100098       2.84       3.10  77.339996  1230.550049
# 7920     0.7753  2705.570068       2.86       3.14  77.300003  1230.800049
# 7921     0.7796  2658.689941       2.81       3.08  77.400002  1233.849976
# 7922     0.7797  2641.250000       2.81       3.08  77.559998  1230.800049
# 7923     0.7808  2682.629883       2.84       3.12  75.680000  1225.400024
# 7924     0.7855  2711.739990       2.87       3.15  74.839996  1214.949951
# 7925     0.7825  2740.370117       2.84       3.14  71.250000  1231.150024
# 7926     0.7708  2723.060059       2.91       3.22  71.110001  1232.099976
#
#       var6(t+4)   var7(t+4)  var8(t+4)
# 5        1.3951  142.800003     0.6086
# 6        1.4006  144.300003     0.6161
# 7        1.4008  143.800003     0.6131
# 8        1.4006  143.449997     0.6103
# 9        1.3992  142.500000     0.6020
# 10       1.3916  142.449997     0.6030
# 11       1.3963  142.550003     0.6019
# 12       1.3924  143.850006     0.6053
# 23       1.3873  146.699997     0.6247
# 24       1.3872  146.800003     0.6200
# 25       1.3872  146.850006     0.6190
# 26       1.3889  147.300003     0.6190
# 27       1.4043  149.130005     0.6179
# 28       1.4286  149.699997     0.6173
# 29       1.4166  150.570007     0.6181
# 30       1.4090  149.979996     0.6182
# 31       1.4130  150.649994     0.6198
# 32       1.4134  150.979996     0.6182
# 33       1.4144  151.080002     0.6208
# 34       1.4085  148.649994     0.6129
# 35       1.4053  150.550003     0.6133
# 36       1.4088  152.759995     0.6221
# 37       1.4150  152.850006     0.6243
# 38       1.4114  152.660004     0.6268
# 39       1.4079  152.339996     0.6270
# 40       1.4086  150.779999     0.6236
# 41       1.4132  149.949997     0.6238
# 42       1.4215  150.449997     0.6260
# 43       1.4296  150.380005     0.6256
# 44       1.4327  150.779999     0.6250
# ...         ...         ...        ...
# 7897     1.3768  112.620003     0.7617
# 7898     1.3791  112.879997     0.7598
# 7899     1.3774  112.919998     0.7586
# 7900     1.3854  113.379997     0.7631
# 7901     1.3816  113.480003     0.7661
# 7902     1.3845  113.959999     0.7673
# 7903     1.3891  113.660004     0.7702
# 7904     1.4010  114.190002     0.7696
# 7905     1.4128  113.790001     0.7684
# 7906     1.4188  113.559998     0.7633
# 7907     1.4144  113.345001     0.7622
# 7908     1.4100  113.129997     0.7611
# 7909     1.4085  112.709999     0.7572
# 7910     1.4061  112.260002     0.7580
# 7911     1.4053  112.019997     0.7602
# 7912     1.4002  111.820000     0.7594
# 7913     1.4006  112.160004     0.7570
# 7914     1.4025  112.209999     0.7612
# 7915     1.4049  112.110001     0.7656
# 7916     1.4021  112.519997     0.7666
# 7917     1.4112  112.779999     0.7708
# 7918     1.4136  112.120003     0.7703
# 7919     1.4140  112.580002     0.7753
# 7920     1.4116  112.540001     0.7796
# 7921     1.4108  111.650002     0.7797
# 7922     1.4136  112.489998     0.7808
# 7923     1.4061  112.760002     0.7855
# 7924     1.4104  112.860001     0.7825
# 7925     1.3910  112.790001     0.7708
# 7926     1.3891  113.089996     0.7713
#
# [6432 rows x 80 columns]

# %%
#look_back = 5
number_of_variables = 8
reframed.drop(reframed.columns[-1 * number_of_variables + 1:], axis=1, inplace=True)
print(reframed.head())
# Out:
#     var1(t-5)  var2(t-5)  var3(t-5)  var4(t-5)   var5(t-5)  var6(t-5)  \
# 5  278.209991       8.05       8.92  18.629999  475.250000     1.3820
# 6  280.170013       8.06       8.87  18.450001  469.100006     1.3864
# 7  282.160004       7.97       8.78  18.549999  466.500000     1.3883
# 8  289.109985       7.79       8.55  18.629999  449.000000     1.4029
# 9  288.730011       7.84       8.60  18.600000  449.500000     1.3988
#
#     var7(t-5)  var8(t-5)   var1(t-4)  var2(t-4)  ...  var8(t+2)   var1(t+3)  \
# 5  139.779999     0.5942  280.170013       8.06  ...     0.6157  288.459991
# 6  140.449997     0.5956  282.160004       7.97  ...     0.6085  293.470001
# 7  140.600006     0.5977  289.109985       7.79  ...     0.6086  295.089996
# 8  143.300003     0.6120  288.730011       7.84  ...     0.6161  293.450012
# 9  143.520004     0.6200  290.760010       7.81  ...     0.6131  296.720001
#
#    var2(t+3)  var3(t+3)  var4(t+3)   var5(t+3)  var6(t+3)   var7(t+3)  \
# 5       7.85       8.72  18.680000  455.000000     1.3982  142.250000
# 6       7.78       8.64  18.750000  453.000000     1.3951  142.800003
# 7       7.76       8.58  18.780001  452.750000     1.4006  144.300003
# 8       7.66       8.50  18.650000  453.500000     1.4008  143.800003
# 9       7.68       8.53  18.750000  456.549988     1.4006  143.449997
#
#    var8(t+3)   var1(t+4)
# 5     0.6085  293.470001
# 6     0.6086  295.089996
# 7     0.6161  293.450012
# 8     0.6131  296.720001
# 9     0.6103  297.279999
#
# [5 rows x 73 columns]

# %%
reframed.drop(reframed.columns[look_back*number_of_variables:-1], axis=1, inplace=True)
print(reframed.head())
# Out:
#     var1(t-5)  var2(t-5)  var3(t-5)  var4(t-5)   var5(t-5)  var6(t-5)  \
# 5  278.209991       8.05       8.92  18.629999  475.250000     1.3820
# 6  280.170013       8.06       8.87  18.450001  469.100006     1.3864
# 7  282.160004       7.97       8.78  18.549999  466.500000     1.3883
# 8  289.109985       7.79       8.55  18.629999  449.000000     1.4029
# 9  288.730011       7.84       8.60  18.600000  449.500000     1.3988
#
#     var7(t-5)  var8(t-5)   var1(t-4)  var2(t-4)  ...  var8(t-2)   var1(t-1)  \
# 5  139.779999     0.5942  280.170013       8.06  ...     0.6120  288.730011
# 6  140.449997     0.5956  282.160004       7.97  ...     0.6200  290.760010
# 7  140.600006     0.5977  289.109985       7.79  ...     0.6152  290.100006
# 8  143.300003     0.6120  288.730011       7.84  ...     0.6137  289.829987
# 9  143.520004     0.6200  290.760010       7.81  ...     0.6157  288.459991
#
#    var2(t-1)  var3(t-1)  var4(t-1)   var5(t-1)  var6(t-1)   var7(t-1)  \
# 5       7.84       8.60      18.60  449.500000     1.3988  143.520004
# 6       7.81       8.56      18.60  453.100006     1.4041  143.399994
# 7       7.69       8.49      18.58  451.000000     1.4041  144.100006
# 8       7.67       8.45      18.65  442.899994     1.3992  145.449997
# 9       7.85       8.72      18.68  455.000000     1.3982  142.250000
#
#    var8(t-1)   var1(t+4)
# 5     0.6200  293.470001
# 6     0.6152  295.089996
# 7     0.6137  293.450012
# 8     0.6157  296.720001
# 9     0.6085  297.279999
#
# [5 rows x 41 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(reframed)
# Out:
# /home/tjiang20/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning:
#
# Data with input dtype float32 were all converted to float64 by MinMaxScaler.

# %%
scaled.shape
# Out:
# (6432, 41)

# %%
#splitting data 
n_train_hours = int(len(scaled) * 0.7)

# %%
train = scaled[:n_train_hours, :]
test = scaled[n_train_hours:, :]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]


# target = -1 * number_of_variables
# look_back = 1
# number_of_variables = 8
# train_X, train_y = train[:, :(look_back * number_of_variables)], train[:, -1]
# test_X, test_y = test[:, :(look_back * number_of_variables) ], test[:, -1]

# %%
train_X
# Out:
# array([[0.02005667, 0.81340211, 0.85214452, ..., 0.42244934, 0.81285218,
#         0.41605007],
#        [0.02078077, 0.81443306, 0.84650116, ..., 0.42700097, 0.81141338,
#         0.40239036],
#        [0.02151595, 0.80515465, 0.83634313, ..., 0.42700097, 0.8198058 ,
#         0.39812169],
#        ...,
#        [0.26683982, 0.11752577, 0.27539504, ..., 0.28959118, 0.24745233,
#         0.3901536 ],
#        [0.25853119, 0.11340207, 0.26975171, ..., 0.27997254, 0.24493465,
#         0.37251001],
#        [0.25419032, 0.11030928, 0.2595937 , ..., 0.30882858, 0.24193741,
#         0.39299932]])

# %%
train_y
# Out:
# array([0.02569426, 0.02629275, 0.02568688, ..., 0.25725295, 0.25675053,
#        0.25982791])

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (4502, 1, 40) (4502,) (1930, 1, 40) (1930,)

# %%
multi_model = Sequential()
multi_model.add(LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2])))
multi_model.add(Dense(1))
multi_model.compile(loss='mae', optimizer='adam')
multi_history = multi_model.fit(train_X, train_y, epochs=50, batch_size=100, validation_data=(test_X, test_y), verbose=1, shuffle=False)
# Out:
# Train on 4502 samples, validate on 1930 samples
# Epoch 1/50
# 4502/4502 [==============================] - 1s 237us/step - loss: 0.0607 - val_loss: 0.1393
# Epoch 2/50
# 4502/4502 [==============================] - 0s 71us/step - loss: 0.1304 - val_loss: 0.1359
# Epoch 3/50
# 4502/4502 [==============================] - 0s 71us/step - loss: 0.0889 - val_loss: 0.0920
# Epoch 4/50
# 4502/4502 [==============================] - 0s 72us/step - loss: 0.0934 - val_loss: 0.0931
# Epoch 5/50
# 4502/4502 [==============================] - 0s 71us/step - loss: 0.0448 - val_loss: 0.1158
# Epoch 6/50
# 4502/4502 [==============================] - 0s 70us/step - loss: 0.0303 - val_loss: 0.1289
# Epoch 7/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0305 - val_loss: 0.1134
# Epoch 8/50
# 4502/4502 [==============================] - 0s 71us/step - loss: 0.0479 - val_loss: 0.1023
# Epoch 9/50
# 4502/4502 [==============================] - 0s 71us/step - loss: 0.0184 - val_loss: 0.1367
# Epoch 10/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0266 - val_loss: 0.1348
# Epoch 11/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0313 - val_loss: 0.1636
# Epoch 12/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0396 - val_loss: 0.1755
# Epoch 13/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0673 - val_loss: 0.1069
# Epoch 14/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.1024 - val_loss: 0.0418
# Epoch 15/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0559 - val_loss: 0.0265
# Epoch 16/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0315 - val_loss: 0.0606
# Epoch 17/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0535 - val_loss: 0.0957
# Epoch 18/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0256 - val_loss: 0.0690
# Epoch 19/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0324 - val_loss: 0.1565
# Epoch 20/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0392 - val_loss: 0.1307
# Epoch 21/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0461 - val_loss: 0.1061
# Epoch 22/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0214 - val_loss: 0.0705
# Epoch 23/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0217 - val_loss: 0.1263
# Epoch 24/50
# 4502/4502 [==============================] - 0s 70us/step - loss: 0.0299 - val_loss: 0.1096
# Epoch 25/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0273 - val_loss: 0.0751
# Epoch 26/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0203 - val_loss: 0.0766
# Epoch 27/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0236 - val_loss: 0.0988
# Epoch 28/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0300 - val_loss: 0.1181
# Epoch 29/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0222 - val_loss: 0.0841
# Epoch 30/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0348 - val_loss: 0.0697
# Epoch 31/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0285 - val_loss: 0.0840
# Epoch 32/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0271 - val_loss: 0.0775
# Epoch 33/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0216 - val_loss: 0.0403
# Epoch 34/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0153 - val_loss: 0.0412
# Epoch 35/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0207 - val_loss: 0.0417
# Epoch 36/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0162 - val_loss: 0.0686
# Epoch 37/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0185 - val_loss: 0.0453
# Epoch 38/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0192 - val_loss: 0.0452
# Epoch 39/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0121 - val_loss: 0.0497
# Epoch 40/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0137 - val_loss: 0.0577
# Epoch 41/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0140 - val_loss: 0.0435
# Epoch 42/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0247 - val_loss: 0.0439
# Epoch 43/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0133 - val_loss: 0.0351
# Epoch 44/50
# 4502/4502 [==============================] - 0s 70us/step - loss: 0.0144 - val_loss: 0.0449
# Epoch 45/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0189 - val_loss: 0.0489
# Epoch 46/50
# 4502/4502 [==============================] - 0s 71us/step - loss: 0.0210 - val_loss: 0.0437
# Epoch 47/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0180 - val_loss: 0.0499
# Epoch 48/50
# 4502/4502 [==============================] - 0s 68us/step - loss: 0.0153 - val_loss: 0.0427
# Epoch 49/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0109 - val_loss: 0.0476
# Epoch 50/50
# 4502/4502 [==============================] - 0s 69us/step - loss: 0.0126 - val_loss: 0.0360

# %%
#plot result 
pyplot.plot(multi_history.history['loss'], label='multi_train')
pyplot.plot(multi_history.history['val_loss'], label='multi_test')
pyplot.legend()
pyplot.show()

# %%
#plot prediction
yhat = multi_model.predict(test_X)
pyplot.plot(yhat, label='predict')
pyplot.plot(test_y, label='true')
pyplot.legend()
pyplot.show()

# %%
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
test_X
# Out:
# array([[0.25372485, 0.10618558, 0.26072237, ..., 0.30814152, 0.23498379,
#         0.39271487],
#        [0.25655471, 0.11546392, 0.28103838, ..., 0.29087941, 0.2357031 ,
#         0.37791684],
#        [0.2576113 , 0.11237114, 0.27313771, ..., 0.29603231, 0.24565396,
#         0.39356857],
#        ...,
#        [0.94016249, 0.27938144, 0.20316029, ..., 0.43550329, 0.44191343,
#         0.85799661],
#        [0.93979305, 0.2845361 , 0.20654629, ..., 0.43344211, 0.44143386,
#         0.87023337],
#        [0.93539671, 0.2845361 , 0.20654629, ..., 0.43275504, 0.43076368,
#         0.87051782]])

# %%
#test_X[:, 1:]
yhat
# Out:
# array([[0.25951555],
#        [0.2574719 ],
#        [0.25947982],
#        ...,
#        [0.8132159 ],
#        [0.8093687 ],
#        [0.8031953 ]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, :]), axis=1)

# %%
inv_yhat.shape
# Out:
# (1930, 41)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
inv_yhat = inv_yhat[:,0]

# %%
inv_yhat
# Out:
# array([ 926.3844849 ,  920.85263264,  926.28776179, ..., 2425.15722508,
#        2414.74355797, 2398.03312736])

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))

# %%
inv_y = concatenate((test_y, test_X[:, :]), axis=1)

# %%
inv_y
# Out:
# array([[0.25690568, 0.25372485, 0.10618558, ..., 0.30814152, 0.23498379,
#         0.39271487],
#        [0.25838712, 0.25655471, 0.11546392, ..., 0.29087941, 0.2357031 ,
#         0.37791684],
#        [0.24844559, 0.2576113 , 0.11237114, ..., 0.29603231, 0.24565396,
#         0.39356857],
#        ...,
#        [0.91908985, 0.94016249, 0.27938144, ..., 0.43550329, 0.44191343,
#         0.85799661],
#        [0.92966685, 0.93979305, 0.2845361 , ..., 0.43344211, 0.44143386,
#         0.87023337],
#        [0.92327189, 0.93539671, 0.2845361 , ..., 0.43275504, 0.43076368,
#         0.87051782]])

# %%
inv_y = scaler.inverse_transform(inv_y)

# %%
inv_y
# Out:
# array([[9.19320007e+02, 2.62113091e+00, 2.31080417e+00, ...,
#         1.01422086e+02, 5.56373310e-01, 1.28693238e+03],
#        [9.23330017e+02, 2.64858063e+00, 2.39301027e+00, ...,
#         9.99822538e+01, 5.56626075e-01, 1.24687663e+03],
#        [8.96419983e+02, 2.65882947e+00, 2.36560824e+00, ...,
#         1.00412058e+02, 5.60122810e-01, 1.28924320e+03],
#        ...,
#        [2.71173999e+03, 9.27957582e+00, 3.84531945e+00, ...,
#         1.12045332e+02, 6.29088390e-01, 2.54637095e+03],
#        [2.74037012e+03, 9.27599229e+00, 3.89098973e+00, ...,
#         1.11873409e+02, 6.28919869e-01, 2.57949379e+03],
#        [2.72306006e+03, 9.23334779e+00, 3.89098973e+00, ...,
#         1.11816101e+02, 6.25170369e-01, 2.58026375e+03]])

# %%
inv_y = inv_y[:,0]

# %%
inv_y
# Out:
# array([ 919.32000732,  923.33001709,  896.41998291, ..., 2711.73999023,
#        2740.37011719, 2723.06005859])

# %%
inv_yhat
# Out:
# array([ 926.3844849 ,  920.85263264,  926.28776179, ..., 2425.15722508,
#        2414.74355797, 2398.03312736])

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 128.322

# %%
predictDates = data.tail(len(inv_y)).index
actual_chart = go.Scatter(x=predictDates, y=inv_y, name= 'Actual Price')
multi_predict_chart = go.Scatter(x=predictDates, y=inv_yhat, name= 'Multi Predict Price')
#predict_chart = go.Scatter(x=predictDates, y=yhat_reshape, name= 'Predict Price')
#py.iplot([predict_chart, multi_predict_chart, actual_chart])
py.iplot([multi_predict_chart, actual_chart])
# Out:
# <div id="bae2f8af-1a65-42b6-9e6a-2b9c90a6dab4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bae2f8af-1a65-42b6-9e6a-2b9c90a6dab4", [{"name": "Multi Predict Price", "x": [20110308, 20110309, 20110310, 20110311, 20110314, 20110315, 20110316, 20110317, 20110318, 20110321, 20110322, 20110323, 20110324, 20110325, 20110328, 20110329, 20110330, 20110331, 20110401, 20110404, 20110405, 20110406, 20110407, 20110408, 20110411, 20110412, 20110413, 20110414, 20110415, 20110418, 20110419, 20110420, 20110421, 20110425, 20110426, 20110427, 20110428, 20110429, 20110502, 20110503, 20110504, 20110505, 20110506, 20110509, 20110510, 20110511, 20110512, 20110513, 20110516, 20110517, 20110518, 20110519, 20110520, 20110523, 20110524, 20110525, 20110526, 20110527, 20110531, 20110601, 20110602, 20110603, 20110606, 20110607, 20110608, 20110609, 20110610, 20110613, 20110614, 20110615, 20110616, 20110617, 20110620, 20110621, 20110622, 20110623, 20110624, 20110627, 20110628, 20110629, 20110630, 20110701, 20110705, 20110706, 20110707, 20110708, 20110711, 20110712, 20110713, 20110714, 20110715, 20110718, 20110719, 20110720, 20110721, 20110722, 20110725, 20110726, 20110727, 20110728, 20110729, 20110801, 20110802, 20110803, 20110804, 20110805, 20110808, 20110809, 20110810, 20110811, 20110812, 20110815, 20110816, 20110817, 20110818, 20110819, 20110822, 20110823, 20110824, 20110825, 20110826, 20110829, 20110830, 20110831, 20110901, 20110902, 20110906, 20110907, 20110908, 20110909, 20110912, 20110913, 20110914, 20110915, 20110916, 20110919, 20110920, 20110921, 20110922, 20110923, 20110926, 20110927, 20110928, 20110929, 20110930, 20111003, 20111004, 20111005, 20111006, 20111007, 20111010, 20111011, 20111012, 20111013, 20111014, 20111017, 20111018, 20111019, 20111020, 20111021, 20111024, 20111025, 20111026, 20111027, 20111028, 20111031, 20111101, 20111102, 20111103, 20111104, 20111107, 20111108, 20111109, 20111110, 20111111, 20111114, 20111115, 20111116, 20111117, 20111118, 20111121, 20111122, 20111123, 20111125, 20111128, 20111129, 20111130, 20111201, 20111202, 20111205, 20111206, 20111207, 20111208, 20111209, 20111212, 20111213, 20111214, 20111215, 20111216, 20111219, 20111220, 20111221, 20111222, 20111223, 20111227, 20111228, 20111229, 20111230, 20120103, 20120104, 20120105, 20120106, 20120109, 20120110, 20120111, 20120112, 20120113, 20120117, 20120118, 20120119, 20120120, 20120123, 20120124, 20120125, 20120126, 20120127, 20120130, 20120131, 20120201, 20120202, 20120203, 20120206, 20120207, 20120208, 20120209, 20120210, 20120213, 20120214, 20120215, 20120216, 20120217, 20120221, 20120222, 20120223, 20120224, 20120227, 20120228, 20120229, 20120301, 20120302, 20120305, 20120306, 20120307, 20120308, 20120309, 20120312, 20120313, 20120314, 20120315, 20120316, 20120319, 20120320, 20120321, 20120322, 20120323, 20120326, 20120327, 20120328, 20120329, 20120330, 20120402, 20120403, 20120404, 20120405, 20120409, 20120410, 20120411, 20120412, 20120413, 20120416, 20120417, 20120418, 20120419, 20120420, 20120423, 20120424, 20120425, 20120426, 20120427, 20120430, 20120501, 20120502, 20120503, 20120504, 20120507, 20120508, 20120509, 20120510, 20120511, 20120514, 20120515, 20120516, 20120517, 20120518, 20120521, 20120522, 20120523, 20120524, 20120525, 20120529, 20120530, 20120531, 20120601, 20120604, 20120605, 20120606, 20120607, 20120608, 20120611, 20120612, 20120613, 20120614, 20120615, 20120618, 20120619, 20120620, 20120621, 20120622, 20120625, 20120626, 20120627, 20120628, 20120629, 20120702, 20120703, 20120705, 20120706, 20120709, 20120710, 20120711, 20120712, 20120713, 20120716, 20120717, 20120718, 20120719, 20120720, 20120723, 20120724, 20120725, 20120726, 20120727, 20120730, 20120731, 20120801, 20120802, 20120803, 20120806, 20120807, 20120808, 20120809, 20120810, 20120813, 20120814 ...
